# %%
from fastai.vision import *
from pathlib import Path

# %%
import cv2

# %%
# download_images("carlink.txt", '.', max_pics=290)

# %%
path = Path("data")

# %%
get_transforms()
# Out:
# ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmPixel (flip_lr), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (zoom), kwargs={'scale': (1.0, 1.1), 'row_pct': (0, 1), 'col_pct': (0, 1)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmLighting (brightness), kwargs={'change': (0.4, 0.6)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
# ...

# %%
data = ImageDataBunch.from_folder(path,train='train',valid='valid', size=256, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch()

# %%
data.classes
# Out:
# ['helmet', 'nothelmet']

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.model.cuda()
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# learn.fit_one_cycle(3)

# %%
# learn.save('stage1')

# %%
test = ImageList.from_folder('data/test')
len(test)
# Out:
# 4

# %%
# learn.export()

# %%
learn.load('stage1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (432 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# helmet,helmet,helmet,helmet,helmet
# Path: data;
#
# Valid: LabelList (75 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# helmet,helmet,helmet,helmet,helmet
# Path: data;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
imgloc='data/test/test4.jpg'
img = open_image(imgloc)
a,b,c = learn.predict(img)
print(a)
sorter(str(a),imgloc)
img
# Out:
# nothelmet
# Image (3, 448, 800)

# %%
def sorter(a,imgloc):
    name = imgloc.split('.')[0].split('/')[-1]
    img = cv2.imread(imgloc)
    if a=='helmet':
        cv2.imwrite('output/helmet/'+name+'.jpg',img)
        
    else:
        cv2.imwrite('output/nohelmet/'+name+'.jpg',img)

# %%
output_dir = Path('output/helmet')
# !dir {output_dir}
output_dir

# %%
# !pip freeze >requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -pencv-python 4.1.1.26 (c:\users\asish\appdata\local\programs\python\python37\lib\site-packages): Parse error at "'-pencv-p'": Expected W:(abcd...)
